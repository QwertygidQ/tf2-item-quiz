# %%
import requests
from json import dumps

# %%
def get_weapon_info(weapon):
    r = requests.get('https://wiki.teamfortress.com/w/api.php?action=query&prop=revisions&rvprop=content&format=json&titles=' + weapon + '&rvsection=0&redirects')

    json = r.json()
    json = json['query']['pages']
    json = json[list(json.keys())[0]]
    title = json['title']
    json = json['revisions'][0]['*']
    info = json.split('\n')

    info = list(map(str.strip, info))
    info = list(filter(lambda x: len(x) > 0 and x[0] == '|', info))
    info = list(map(lambda x: x[2:], info))

    d = {}
    for obj in info:
        temp = list(map(str.strip, obj.split('=')))
        d[temp[0]] = temp[1]
    d['name'] = title

    proper_dict = {
        'name': d['name'],
        'tfclass': d['used-by'][2:-2],
        'level': 'Level ' + d['level'] + ' ' + d['item-kind']
    }
    attrs = list(filter(lambda k: k.startswith('att'), d))
    proper_dict['attrs'] = list(map(lambda x: {'positive': x.endswith('positive'), 'text': d[x].replace('<br>', ' \n')}, attrs))

    r = requests.get('https://wiki.teamfortress.com/w/api.php?action=query&prop=images&format=json&titles=' + title)

    json = r.json()
    json = json['query']['pages']
    json = json[list(json.keys())[0]]['images']

    image = next(x for x in json if x['title'].startswith('File:Backpack'))['title']
    
    r = requests.get('https://wiki.teamfortress.com/w/api.php?action=query&titles=' + image + '&prop=imageinfo&iiprop=url&format=json')
    json = r.json()
    json = json['query']['pages']
    image = json[list(json.keys())[0]]['imageinfo'][0]['url']
    
    proper_dict['img'] = image
    return proper_dict

# %%
get_weapon_info('Claidheamh Mòr')
# Out:
# {'name': 'Claidheamh Mòr',
#  'tfclass': 'Demoman',
#  'level': 'Level 5 Sword',
#  'attrs': [{'positive': False, 'text': 'When weapon is active:'},
#   {'positive': False,
#    'text': 'This Weapon has a large melee range and deploys and holsters slower'},
#   {'positive': True, 'text': '0.5 sec increase in charge duration'},
#   {'positive': True, 'text': 'Melee kills refill 25% of your charge meter.'},
#   {'positive': False, 'text': 'No random critical hits'},
#   {'positive': False, 'text': '15% damage vulnerability on wearer'}],
#  'img': 'https://wiki.teamfortress.com/w/images/a/af/Backpack_Claidheamh_M%C3%B2r.png'}

# %%
weapons = []

# %%
r = requests.get('https://wiki.teamfortress.com/w/api.php?action=query&titles=Weapons&prop=links&format=json&redirects')
tmp_json = r.json()
tmp_json = tmp_json['query']['pages']
tmp_json = tmp_json[list(tmp_json.keys())[0]]['links']
weapons = [*weapons, *tmp_json]

plcontinue = '1585|0|Apoco-Fists'
while plcontinue != '':
    r = requests.get('https://wiki.teamfortress.com/w/api.php?action=query&titles=Weapons&prop=links&format=json&redirects&plcontinue=' + plcontinue)
    tmp_json = r.json()
    try:
        plcontinue = tmp_json['continue']['plcontinue']
    except:
        break
    tmp_json = tmp_json['query']['pages']
    tmp_json = tmp_json[list(tmp_json.keys())[0]]['links']
    print(plcontinue)
    weapons = [*weapons, *tmp_json]
# Out:
# 1585|0|August_19,_2008_Patch
# 1585|0|Backburner
# 1585|0|Black_Box
# 1585|0|Bread_Bite
# 1585|0|Classic
# 1585|0|Cozy_Camper
# 1585|0|December_10,_2014_Patch
# 1585|0|Detonator
# 1585|0|Enforcer
# 1585|0|Execution
# 1585|0|Fencing
# 1585|0|Fortified_Compound
# 1585|0|Golden_Wrench
# 1585|0|Hitman's_Heatmaker
# 1585|0|Invis_Watch
# 1585|0|July_1,_2010_Patch
# 1585|0|June_8,_2011_Patch
# 1585|0|List_of_item_attributes
# 1585|0|Mann-Conomy_Update
# 1585|0|Market_Gardener
# 1585|0|Memory_Maker
# 1585|0|November_13,_2014_Patch
# 1585|0|October_27,_2011_Patch
# 1585|0|Panic_Attack
# 1585|0|Pyro_Update
# 1585|0|Rescue_Ranger
# 1585|0|Sandvich
# 1585|0|Scream_Fortress_Update
# 1585|0|Shooting_Star
# 1585|0|Sniper_vs._Spy_Update
# 1585|0|Sticky_Jumper
# 1585|0|Three-Rune_Blade
# 1585|0|Vaccinator
# 1585|0|Wrench

# %%
links = list(map(lambda x: x['title'], weapons))
links
# Out:
# ['AWPer Hand',
#  'Achievements',
#  'Afterburn',
#  'Air Strike',
#  "Ali Baba's Wee Booties",
#  'All classes',
#  'Ambassador',
#  'Ammo',
#  'Amputator',
#  'Ap-Sap',
#  'Apoco-Fists',
#  'April 15, 2010 Patch',
#  'April 28, 2010 Patch',
#  'April 28, 2011 Patch',
#  'April 29, 2008 Patch',
#  'Armageddon',
#  'Atomizer',
#  'August 15, 2012 Patch',
#  'August 18, 2011 Patch',
#  'August 18, 2015 Patch',
#  'August 19, 2008 Patch',
#  'August 2, 2012 Patch',
#  'August 3, 2011 Patch',
#  'Australian Christmas',
#  'Australian Christmas 2011',
#  'Axtinguisher',
#  'B.A.S.E. Jumper',
#  "Baby Face's Blaster",
#  'Back Scatter',
#  'Back Scratcher',
#  'Backburner',
#  'Backstab',
#  'Bat',
#  'Bat Outta Hell',
#  'Batsaber',
#  "Battalion's Backup",
#  'Bazaar Bargain',
#  "Beggar's Bazooka",
#  'Big Earner',
#  'Big Kill',
#  'Black Box',
#  'Black Rose',
#  'Bleeding',
#  'Blutsauger',
#  'Bonesaw',
#  'Bonk! Atomic Punch',
#  'Bootlegger',
#  'Boston Basher',
#  'Bottle',
#  'Brass Beast',
#  'Bread Bite',
#  'Buff Banner',
#  'Buffalo Steak Sandvich',
#  'Build Tool',
#  'Buildings',
#  'Bushwacka',
#  'C.A.P.P.E.R',
#  'Candy Cane',
#  "Chargin' Targe",
#  'Claidheamh Mòr',
#  'Classic',
#  "Cleaner's Carbine",
#  'Cloak',
#  'Cloak and Dagger',
#  'Concheror',
#  "Conniver's Kunai",
#  'Conscientious Objector',
#  'Contracts',
#  'Cosmetic items',
#  'Cow Mangler 5000',
#  'Cozy Camper',
#  'Crafting',
#  'Crates',
#  'Crit-a-Cola',
#  'Crossing Guard',
#  "Crusader's Crossbow",
#  'Dalokohs Bar',
#  "Darwin's Danger Shield",
#  'Dead Ringer',
#  'Decapitation',
#  'December 10, 2014 Patch',
#  'December 15, 2011 Patch',
#  'December 17, 2009 Patch',
#  'December 17, 2010 Patch',
#  'December 20, 2012 Patch',
#  'December 22, 2014 Patch',
#  'December 8, 2014 Patch',
#  'Degreaser',
#  'Demolish Tool',
#  'Demoman',
#  'Detonator',
#  'Diamondback',
#  'Direct Hit',
#  'Dischord',
#  'Disciplinary Action',
#  'Disguise',
#  'Disguise Kit',
#  'Dispenser',
#  "Dragon's Fury",
#  'Drops',
#  'Enforcer',
#  'Engineer',
#  'Engineer Update',
#  "Enthusiast's Timepiece",
#  'Equalizer',
#  'Equip region',
#  'Escape Plan',
#  'Eureka Effect',
#  'Eureka Effect Taunt',
#  'Eviction Notice',
#  'Execution',
#  'Eyelander',
#  'Family Business',
#  "Fan O'War",
#  'February 11, 2014 Patch',
#  'February 14, 2012 Patch',
#  'February 18, 2015 Patch',
#  'February 19, 2008 Patch',
#  'February 24, 2009 Patch',
#  'February 3, 2011 Patch',
#  'Fencing',
#  'Fire Axe',
#  'First Annual Saxxy Awards',
#  'Fishcake',
#  'Fists',
#  'Fists of Steel',
#  'Flame Thrower',
#  'Flare Gun',
#  'Flying Guillotine',
#  'Force-A-Nature',
#  'Fortified Compound',
#  'Freedom Staff',
#  'Frontier Justice',
#  'Frying Pan',
#  'Gas Blast',
#  'Gas Passer',
#  'Giger Counter',
#  'Gloves of Running Urgently',
#  'Gold Rush Update',
#  'Golden Frying Pan',
#  'Golden Wrench',
#  'Grenade Launcher',
#  'Gunboats',
#  'Gunslinger',
#  'Hadouken',
#  'Half-Zatoichi',
#  'Ham Shank',
#  'Headshot',
#  'Heavy',
#  'Heavy Update',
#  "Hitman's Heatmaker",
#  'Holiday Punch',
#  'Holy Mackerel',
#  'Home Run',
#  'Homewrecker',
#  "Horseless Headless Horsemann's Headtaker",
#  'Hot Hand',
#  'Huntsman',
#  'Huo-Long Heater',
#  'Invasion Update',
#  'Invis Watch',
#  'Iron Bomber',
#  'Iron Curtain',
#  'Item drop system',
#  'Item quality',
#  'Item quality distribution',
#  'Item timeline',
#  'Items',
#  'Jag',
#  'Jarate',
#  'July 1, 2010 Patch',
#  'July 1, 2011 Patch',
#  'July 20, 2011 Patch',
#  'July 7, 2016 Patch',
#  'July 8, 2010 Patch',
#  'June 18, 2014 Patch',
#  'June 19, 2008 Patch',
#  'June 23, 2011 Patch',
#  'June 27, 2012 Patch',
#  'June 3, 2011 Patch',
#  'June 8, 2011 Patch',
#  'Jungle Inferno Update',
#  'Kamikaze',
#  'Kill icon',
#  'Killing Gloves of Boxing',
#  'Knife',
#  'Kritzkrieg',
#  'Kukri',
#  "L'Etranger",
#  'Liberty Launcher',
#  'List of item attributes',
#  'Loch-n-Load',
#  'Lollichop',
#  'Loose Cannon',
#  'Love and War Update',
#  'Lugermorph',
#  'Lumbricus Lid',
#  'Machina',
#  'Mad Milk',
#  'Manmelter',
#  'Mann-Conomy Update',
#  'Mann Co. Store',
#  'Mann Co. Supply Crate',
#  'Manniversary Update & Sale',
#  'Mantreads',
#  'March 10, 2011 Patch',
#  'March 12, 2013 Patch',
#  'March 12, 2015 Patch',
#  'March 15, 2012 Patch',
#  'March 18, 2010 Patch',
#  'Market Gardener',
#  'Maul',
#  'May 12, 2011 Patch',
#  'May 20, 2010 Patch',
#  'May 21, 2009 Patch',
#  'Mecha Update',
#  'Medi Gun',
#  'Medic',
#  'Medicating Melody',
#  'Meet Your Match Update',
#  'Memory Maker',
#  'Minigun',
#  'Mmmph',
#  'Mutated Milk',
#  'Natascha',
#  'Necro Smasher',
#  'Neon Annihilator',
#  "Nessie's Nine Iron",
#  'Nostromo Napalmer',
#  'November 10, 2011 Patch',
#  'November 13, 2014 Patch',
#  'November 16, 2012 Patch',
#  'November 19, 2010 Patch',
#  'November 21, 2013 Patch',
#  'November 23, 2011 Patch',
#  'November 29, 2012 Patch',
#  'October 13, 2011 Patch',
#  'October 20, 2017 Patch',
#  'October 26, 2012 Patch',
#  'October 27, 2010 Patch',
#  'October 27, 2011 Patch',
#  'October 29, 2014 Patch',
#  'October 6, 2010 Patch',
#  'October 6, 2015 Patch',
#  'Oktoberfest',
#  'Organ Grinder',
#  'Original',
#  'Overdose',
#  'PDA',
#  'Pain Train',
#  'Panic Attack',
#  'Persian Persuader',
#  'Phlogistinator',
#  'Pistol',
#  'Pomson 6000',
#  'Postal Pummeler',
#  'Powerjack',
#  "Pretty Boy's Pocket Pistol",
#  'Prinny Machete',
#  'Pyro',
#  'Pyro Update',
#  'Pyroland Contracts',
#  'Pyromania Update',
#  'Quackenbirdt',
#  'Quick-Fix',
#  'Quickiebomb Launcher',
#  'Quäckenbirdt',
#  'Rainblower',
#  'Razorback',
#  'Red-Tape Recorder',
#  'Rescue Ranger',
#  'Reserve Shooter',
#  'Reskins',
#  'Revolver',
#  'Righteous Bison',
#  'Robo-Sandvich',
#  'Rocket Jumper',
#  'Rocket Launcher',
#  'SMG',
#  'Sandman',
#  'Sandvich',
#  'Sapper',
#  'Saxxy',
#  'Scattergun',
#  'Scorch Shot',
#  "Scotsman's Skullcutter",
#  'Scottish Handshake',
#  'Scottish Resistance',
#  'Scout',
#  'Scout Update',
#  'Scream Fortress Update',
#  'Second Banana',
#  'Self-Aware Beauty Mark',
#  'September 17, 2014 Patch',
#  'September 21, 2012 Patch',
#  'September 27, 2012 Patch',
#  'September 30, 2010 Patch',
#  'Shahanshah',
#  'Sharp Dresser',
#  'Sharpened Volcano Fragment',
#  'Shooting Star',
#  'Short Circuit',
#  'Shortstop',
#  'Shotgun',
#  'Shovel',
#  'Showdown',
#  'Skewer',
#  'Snack Attack',
#  'Sniper',
#  'Sniper Rifle',
#  'Sniper vs. Spy Update',
#  'Soda Popper',
#  'Soldier',
#  'Solemn Vow',
#  'Southern Hospitality',
#  'Spectral Halloween Special',
#  'Spinal Tap',
#  'Splendid Screen',
#  'Spy',
#  'Spy-cicle',
#  'Sticky Jumper',
#  'Stickybomb Launcher',
#  'Stock weapons',
#  'Styles',
#  'Sun-on-a-Stick',
#  'Sydney Sleeper',
#  'Syringe Gun',
#  'Taunts',
#  'Thermal Thruster',
#  'Third Degree',
#  'Three-Rune Blade',
#  'Tide Turner',
#  'Tomislav',
#  'Trading',
#  'Triad Pack',
#  "Tribalman's Shiv",
#  'Two Cities Update',
#  'Ubersaw',
#  'Ullapool Caber',
#  'Unarmed Combat',
#  'Vaccinator',
#  'Very Scary Halloween Special',
#  'Vita-Saw',
#  'WAR! Update',
#  'Wanga Prick',
#  "Warrior's Spirit",
#  'Widowmaker',
#  'Winger',
#  'Wrangler',
#  'Wrap Assassin']

# %%
weapon_jsons = []
for link in links:
    try:
        info = get_weapon_info(link)
        print(link)
        weapon_jsons.append(info)
    except:
        continue
# Out:
# AWPer Hand
# Air Strike
# Ali Baba's Wee Booties
# Ambassador
# Amputator
# Ap-Sap
# Apoco-Fists
# Atomizer
# Axtinguisher
# B.A.S.E. Jumper
# Baby Face's Blaster
# Back Scatter
# Back Scratcher
# Backburner
# Bat
# Bat Outta Hell
# Battalion's Backup
# Bazaar Bargain
# Beggar's Bazooka
# Big Earner
# Big Kill
# Black Box
# Black Rose
# Blutsauger
# Bonesaw
# Bonk! Atomic Punch
# Bootlegger
# Boston Basher
# Bottle
# Brass Beast
# Bread Bite
# Buff Banner
# Buffalo Steak Sandvich
# Build Tool
# Bushwacka
# Candy Cane
# Chargin' Targe
# Claidheamh Mòr
# Classic
# Cleaner's Carbine
# Cloak and Dagger
# Concheror
# Conniver's Kunai
# Conscientious Objector
# Cow Mangler 5000
# Cozy Camper
# Crit-a-Cola
# Crossing Guard
# Crusader's Crossbow
# Dalokohs Bar
# Darwin's Danger Shield
# Dead Ringer
# Degreaser
# Demolish Tool
# Detonator
# Diamondback
# Direct Hit
# Disciplinary Action
# Disguise Kit
# Dragon's Fury
# Enforcer
# Enthusiast's Timepiece
# Equalizer
# Escape Plan
# Eureka Effect
# Eureka Effect Taunt
# Eviction Notice
# Eyelander
# Family Business
# Fan O'War
# Fire Axe
# Fishcake
# Fists
# Fists of Steel
# Flame Thrower
# Flare Gun
# Flying Guillotine
# Force-A-Nature
# Fortified Compound
# Freedom Staff
# Frontier Justice
# Frying Pan
# Gas Passer
# Gloves of Running Urgently
# Golden Wrench
# Grenade Launcher
# Gunboats
# Gunslinger
# Half-Zatoichi
# Ham Shank
# Hitman's Heatmaker
# Holiday Punch
# Holy Mackerel
# Homewrecker
# Horseless Headless Horsemann's Headtaker
# Hot Hand
# Huntsman
# Huo-Long Heater
# Invis Watch
# Iron Bomber
# Iron Curtain
# Jarate
# Killing Gloves of Boxing
# Knife
# Kritzkrieg
# Kukri
# L'Etranger
# Liberty Launcher
# Loch-n-Load
# Lollichop
# Loose Cannon
# Lugermorph
# Lumbricus Lid
# Machina
# Mad Milk
# Manmelter
# Mantreads
# Market Gardener
# Maul
# Medi Gun
# Memory Maker
# Minigun
# Mutated Milk
# Natascha
# Necro Smasher
# Neon Annihilator
# Nessie's Nine Iron
# Nostromo Napalmer
# Original
# PDA
# Pomson 6000
# Postal Pummeler
# Powerjack
# Pretty Boy's Pocket Pistol
# Prinny Machete
# Quackenbirdt
# Quäckenbirdt
# Reserve Shooter
# SMG
# Sandman
# Sandvich
# Sapper
# Saxxy
# Scattergun
# Scorch Shot
# Scotsman's Skullcutter
# Scottish Handshake
# Scottish Resistance
# Self-Aware Beauty Mark
# Short Circuit
# Spy-cicle
# Sticky Jumper
# Stickybomb Launcher
# Sun-on-a-Stick
# Sydney Sleeper
# Syringe Gun
# Thermal Thruster
# Third Degree
# Three-Rune Blade
# Tide Turner
# Tomislav
# Tribalman's Shiv
# Ubersaw
# Ullapool Caber
# Unarmed Combat
# Vaccinator
# Vita-Saw
# Wanga Prick
# Warrior's Spirit
# Widowmaker
# Winger
# Wrangler
# Wrap Assassin

# %%
shortened_weapon_jsons = [x for i, x in enumerate(weapon_jsons) if x not in weapon_jsons[i + 1:]]

# %%
for x in shortened_weapon_jsons:  # fix errors
    if x['name'] == 'Fists of Steel':
        x['img'] = 'https://wiki.teamfortress.com/w/images/6/6c/Backpack_Fists_of_Steel.png'
    elif x['name'] == 'Loch-n-Load':
        x['img'] = 'https://wiki.teamfortress.com/w/images/9/9e/Backpack_Loch-n-Load.png'
    elif x['name'] == 'Loose Cannon':
        x['img'] = 'https://wiki.teamfortress.com/w/images/d/d4/Backpack_Loose_Cannon.png'
    elif x['name'] == 'Prinny Machete':
        x['img'] = 'https://wiki.teamfortress.com/w/images/e/ef/Backpack_Prinny_Machete.png'
    elif x['name'] == 'Sandvich':
        x['img'] = 'https://wiki.teamfortress.com/w/images/f/f4/Backpack_Sandvich.png'
    elif x['name'] == 'Scottish Handshake':
        x['img'] = 'https://wiki.teamfortress.com/w/images/0/0d/Backpack_Scottish_Handshake.png'
    elif x['name'] == 'Ullapool Caber':
        x['img'] = 'https://wiki.teamfortress.com/w/images/3/31/Backpack_Ullapool_Caber.png'
    elif x['name'] == 'Vaccinator':
        x['img'] = 'https://wiki.teamfortress.com/w/images/8/86/Backpack_Vaccinator.png'
    elif x['name'] == 'Warrior\'s Spirit':
        x['img'] = 'https://wiki.teamfortress.com/w/images/5/5d/Backpack_Warrior%27s_Spirit.png'

# %%
a = list(map(lambda x: x['name'], shortened_weapon_jsons))
b = list(map(lambda x: x['img'], shortened_weapon_jsons))
for i in range(len(a)):
    print(a[i], b[i])
# Out:
# AWPer Hand https://wiki.teamfortress.com/w/images/2/26/Backpack_AWPer_Hand.png
# Air Strike https://wiki.teamfortress.com/w/images/6/68/Backpack_Air_Strike.png
# Ali Baba's Wee Booties https://wiki.teamfortress.com/w/images/6/64/Backpack_Ali_Baba%27s_Wee_Booties.png
# Ambassador https://wiki.teamfortress.com/w/images/d/db/Backpack_Ambassador.png
# Amputator https://wiki.teamfortress.com/w/images/b/b6/Backpack_Amputator.png
# Ap-Sap https://wiki.teamfortress.com/w/images/a/a0/Backpack_Ap-Sap.png
# Apoco-Fists https://wiki.teamfortress.com/w/images/f/f8/Backpack_Apoco-Fists.png
